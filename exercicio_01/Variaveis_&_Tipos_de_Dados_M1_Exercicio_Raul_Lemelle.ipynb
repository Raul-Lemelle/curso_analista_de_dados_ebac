# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
x = "Olá mundo!"
print(x)
# Out:
# Olá mundo!

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %% [markdown]
# ![blockchain3.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
tkt = 320.52
sqv = 3
svv = tkt * sqv
A = svv
print(A)
# Out:
# 961.56

# %%
# (B)
tkt = 119.21
svv = 834.47
sqv = svv / tkt
B = sqv
print(B)
# Out:
# 7.000000000000001

# %%
# (C)
svv = 15378.12
sqv = 5
tkt = svv / sqv
C = tkt
print(C)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
x = cancao.isalpha()
print(x)

y = cancao.isupper()
print(y)

z = cancao.rfind('mundo')
print(z)
# Out:
# False
# False
# 5

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
posicao_selic_1 = noticia.rfind('2,75%')
posicao_selic_2 = noticia.rfind('%')

selic = noticia[posicao_selic_1 : posicao_selic_2 + 1]

posicao_ano = noticia.rfind('6')
ano = noticia[posicao_ano]

print('selic:' , selic)
print('ano:' , ano)
# Out:
# selic: 2,75%
# ano: 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

# %% [markdown]
# Ultilizando a tabela verdade na linguagem Python para verificar a condição False e True para & (AND).

# %%
print(False & True)
# Out:
# False

# %% [markdown]
# Com o resultado acima, testamos novamente para not.

# %%
print(not False)
# Out:
# True

# %% [markdown]
# Para confirmar o resultado, realizamos print para o valor da variável x.

# %%
print(x)
# Out:
# True
